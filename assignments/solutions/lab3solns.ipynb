# %%
import math as m
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
#part 2

# %%
x = sym.symbols("x",cls=sym.Function)
a, t = sym.symbols("a t")
eq = sym.Eq(sym.diff(x(t),t),a*x(t)**2)
eq
# Out:
# Eq(Derivative(x(t), t), a*x(t)**2)

# %%
sym.dsolve(eq, x(t), ics={x(0):1})
# Out:
# Eq(x(t), -1/(a*t - 1))

# %%
#part 3

def LV(t, y):
    N, P = y
    dNdt = a*N - b*N*P #prey
    dPdt = c*N*P - d*P #predator
    return [dNdt, dPdt]

# %%
#part 4

a = 1.8 
b = 0.4 
c = 0.48
d = 1

initial_condition = [10, 10]
tspan = [0, 100]
soln = solve_ivp(
    LV, 
    tspan, 
    initial_condition) 
    
plt.figure(figsize=(8,5), dpi=100)
plt.plot(soln.t, soln.y[0],label="N")
plt.plot(soln.t, soln.y[1],label="P")
plt.xlabel("Time, $t$", fontsize=20)
plt.ylabel("Population Size", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.legend(fontsize=15);

# %%
#part 5

N, P, a, b, c, d = sym.symbols("N, P, a, b, c, d")
dNdt = a*N - b*N*P #prey
dPdt = c*N*P - d*P

sym.nonlinsolve(
    [dNdt, dPdt],
    [N,P]
)
# Out:
# FiniteSet((0, 0), (d/c, a/b))

# %%
#part 6

a = 1.8 
b = 0.4 
c = 0.48
d = 1

print(d/c,a/b)

initial_condition = [d/c,a/b]
tspan = [0, 100]
soln = solve_ivp(
    LV, 
    tspan, 
    initial_condition) 
    
plt.figure(figsize=(8,5), dpi=100)
plt.plot(soln.t, soln.y[0],label="N")
plt.plot(soln.t, soln.y[1],label="P")
plt.xlabel("Time, $t$", fontsize=20)
plt.ylabel("Population Size", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.legend(fontsize=15);
# Out:
# 2.0833333333333335 4.5

# %%
#part 7

a = 1.8 
b = 0.4 
c = 0.48
d = 1

print(d/c,a/b)

initial_condition = [d/c+0.5,a/b+0.5]
tspan = [0, 100]
soln = solve_ivp(
    LV, 
    tspan, 
    initial_condition) 
    
plt.figure(figsize=(8,5), dpi=100)
plt.plot(soln.t, soln.y[0],label="N")
plt.plot(soln.t, soln.y[1],label="P")
plt.xlabel("Time, $t$", fontsize=20)
plt.ylabel("Population Size", fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid()
plt.legend(fontsize=15);
# Out:
# 2.0833333333333335 4.5
